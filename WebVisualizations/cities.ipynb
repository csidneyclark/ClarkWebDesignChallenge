# %%
import pandas as pd

# %%
data = pd.read_csv("cities.csv")

# %%
data.head()
# Out:
#    Unnamed: 0        City  Temperature (F)  Humidity  Cloudiness  Wind Speed  \
# 0           0      Zaraza            76.93        71          31        5.97
# 1           1     Mataura            57.00        68          90        7.00
# 2           2  Butaritari            83.77        70          26        7.83
# 3           3   Busselton            67.57        57          95        5.99
# 4           4      Avarua            82.40        69           3        8.05
#
#    Latitude  Longitude
# 0      9.35     -65.32
# 1    -46.19     168.86
# 2      3.07     172.79
# 3    -33.65     115.33
# 4    -21.21    -159.78

# %%
htmldata = data.to_html()

# %%
htmldata
# Out:
# d>127.87</td>\n    </tr>\n    <tr>\n      <th>455</th>\n      <td>455</td>\n      <td>Slave Lake</td>\n      <td>48.20</td>\n      <td>49</td>\n      <td>75</td>\n      <td>10.29</td>\n      <td>55.28</td>\n      <td>-114.77</td>\n    </tr>\n    <tr>\n      <th>456</th>\n      <td>456</td>\n      <td>Sisimiut</td>\n      <td>25.88</td>\n      <td>89</td>\n      <td>90</td>\n      <td>18.84</td>\n      <td>66.94</td>\n      <td>-53.67</td>\n    </tr>\n    <tr>\n      <th>457</th>\n      <td>457</td>\n      <td>Pyn U Lwin</td>\n      <td>91.40</td>\n      <td>43</td>\n      <td>20</td>\n      <td>9.17</td>\n      <td>22.03</td>\n      <td>96.47</td>\n    </tr>\n    <tr>\n      <th>458</th>\n      <td>458</td>\n      <td>Nuuk</td>\n      <td>30.20</td>\n      <td>54</td>\n      <td>65</td>\n      <td>28.86</td>\n      <td>64.18</td>\n      <td>-51.72</td>\n    </tr>\n    <tr>\n      <th>459</th>\n      <td>459</td>\n      <td>Yook</td>\n      <td>83.98</td>\n      <td>69</td>\n      <td
# ...

# %%
with open("cities.html", "w", encoding="utf-8") as file:
    file.write(htmldata)
